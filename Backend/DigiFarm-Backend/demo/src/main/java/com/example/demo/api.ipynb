# %%
{
    "userType": "farmer",
    "email": "abir@gmail.com",
    "name": "Abir Dey",
    "farmerId": 1,
    "message": "Login successful"
}
#login

# %%
{
    "area": 1.0,
    "fieldName": "FieldB",
    "message": "Field added successfully",
    "crop": "Rice",
    "fieldId": 2
}
http://localhost:8080/api/profile/field/1

# %%
#Get
https://api.openweathermap.org/data/2.5/weather?q=Chittagong&units=metric&appid=008318cca650e6636b5266bf220f8d78

{
    "coord": {
        "lon": 91.5,
        "lat": 22.9167
    },
    "weather": [
        {
            "id": 800,
            "main": "Clear",
            "description": "clear sky",
            "icon": "01d"
        }
    ],
    "base": "stations",
    "main": {
        "temp": 24.82,
        "feels_like": 24.43,
        "temp_min": 24.82,
        "temp_max": 24.82,
        "pressure": 1014,
        "humidity": 41,
        "sea_level": 1014,
        "grnd_level": 1012
    },
    "visibility": 10000,
    "wind": {
        "speed": 1.31,
        "deg": 308,
        "gust": 1.42
    },
    "clouds": {
        "all": 0
    },
    "dt": 1768799302,
    "sys": {
        "country": "BD",
        "sunrise": 1768783001,
        "sunset": 1768822325
    },
    "timezone": 21600,
    "id": 1337200,
    "name": "Chittagong",
    "cod": 200
}

# %%
#post
https://generativelanguage.googleapis.com/v1/models/gemini-2.5-flash:generateContent?key=AIzaSyDIJS5kh_9l7pmXQ5PW4GWwBpSvV4s94Zs

{
  "error": {
    "code": 429,
    "message": "You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. ",
    "status": "RESOURCE_EXHAUSTED"
  }
}

# %%
#GET
http://localhost:8080/api/irrigation/schedules/1

[
    {
        "duration": 30,
        "nextScheduled": "Jan 20, 06:00 am",
        "fieldName": "FieldA",
        "skipIfRain": true,
        "soilMoisture": 70,
        "active": true,
        "startTime": "06:00",
        "lastWatered": "Never",
        "scheduleId": 1,
        "crop": "Rice",
        "fieldId": 1,
        "frequency": "Daily"
    }
]
